# %%
import pandas as pd
x=pd.read_csv("C:/Users/hemap/Downloads/ProjectonPropertyPricePrediction/Dataset/HousePrices.csv")
df=pd.DataFrame(x)
df
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities  ... PoolArea PoolQC  Fence  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   object
#  3   LotFrontage          1753 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   object
#  6   Alley                129 non-null    object
#  7   Property_Shape       2073 non-null   object
#  8   LandContour          2073 non-null   object
#  9   Utilities            2073 non-null   object
#  10  LotConfig            2073 non-null   object
#  11  LandSlope            2073 non-null   object
#  12  Neighborhood         2073 non-null   object
#  13  Condition1           2073 non-null   object
#  14  Condition2           2073 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   Dwell_Type  LotFrontage        LotArea  OverallQual  \
# count  2073.000000  2073.000000  1753.000000    2073.000000  2073.000000
# mean    916.132176    60.556199    72.056475   10717.853353     6.233478
# std     493.014670   159.924810    27.987475    9215.982306     1.517115
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     519.000000    20.000000    60.000000    7620.000000     5.000000
# 50%     932.000000    50.000000    70.000000    9492.000000     6.000000
# 75%    1302.000000    70.000000    83.000000   11601.000000     7.000000
# max    1820.000000  7080.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  2073.000000  2073.000000   2073.000000  2059.000000  2073.000000  ...
# mean      5.835022  1969.445731   1986.617463   101.875668   437.949349  ...
# std       1.360214    30.222647     20.432694   179.169217   448.051119  ...
# ...

# %%
pd.set_option('display.max_rows',81)

# %%
df.isnull().sum()
# Out:
# Id                        0
# Dwell_Type                0
# Zone_Class                0
# LotFrontage             320
# LotArea                   0
# Road_Type                 0
# Alley                  1944
# Property_Shape            0
# LandContour               0
# Utilities                 0
# LotConfig                 0
# LandSlope                 0
# Neighborhood              0
# Condition1                0
# Condition2                0
# Dwelling_Type             0
# HouseStyle                0
# OverallQual               0
# OverallCond               0
# YearBuilt                 0
# YearRemodAdd              0
# RoofStyle                 0
# RoofMatl                  0
# Exterior1st               0
# Exterior2nd               0
# MasVnrType               14
# MasVnrArea               14
# ExterQual                 0
# ExterCond                 0
# Foundation                0
# BsmtQual                 59
# BsmtCond                 59
# BsmtExposure             61
# ...

# %%
for i in df:
    if df[i].dtype==object:
        x=df[i].mode()[0]
        df[i].fillna(x,inplace=True)
    else:
        x=df[i].mean()
        df[i].fillna(x,inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                     0
# Dwell_Type             0
# Zone_Class             0
# LotFrontage            0
# LotArea                0
# Road_Type              0
# Alley                  0
# Property_Shape         0
# LandContour            0
# Utilities              0
# LotConfig              0
# LandSlope              0
# Neighborhood           0
# Condition1             0
# Condition2             0
# Dwelling_Type          0
# HouseStyle             0
# OverallQual            0
# OverallCond            0
# YearBuilt              0
# YearRemodAdd           0
# RoofStyle              0
# RoofMatl               0
# Exterior1st            0
# Exterior2nd            0
# MasVnrType             0
# MasVnrArea             0
# ExterQual              0
# ExterCond              0
# Foundation             0
# BsmtQual               0
# BsmtCond               0
# BsmtExposure           0
# BsmtFinType1           0
# BsmtFinSF1             0
# BsmtFinType2           0
# BsmtFinSF2             0
# ...

# %%
for i in df:
    if df[i].dtype==object:
        from sklearn.preprocessing import LabelEncoder
        le=LabelEncoder()
        df[i]=le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 81 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int32
#  3   LotFrontage          2073 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int32
#  6   Alley                2073 non-null   int32
#  7   Property_Shape       2073 non-null   int32
#  8   LandContour          2073 non-null   int32
#  9   Utilities            2073 non-null   int32
#  10  LotConfig            2073 non-null   int32
#  11  LandSlope            2073 non-null   int32
#  12  Neighborhood         2073 non-null   int32
#  13  Condition1           2073 non-null   int32
#  14  Condition2           2073 non-null   int32
# ...

# %%
df.corr().style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# ...

# %%
a=df.hist(figsize=(40,20),color='pink')

# %%
import statsmodels.api as sm

# %%
df=df.drop("Id",axis=1)

# %%
x=df.drop("Property_Sale_Price",axis=1)
x
# Out:
#       Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  Alley  \
# 0             60           3    65.000000     8450          1      0
# 1             20           3    80.000000     9600          1      0
# 2             60           3    68.000000    11250          1      0
# 3             70           3    60.000000     9550          1      0
# 4             60           3    84.000000    14260          1      0
# ...          ...         ...          ...      ...        ...    ...
# 2068          60           3    72.056475     8755          1      0
# 2069          90           3    63.000000     7711          1      0
# 2070          90           3   313.000000    25000          1      0
# 2071          20           3    52.000000    14375          1      0
# 2072          50           4    98.000000     8820          1      0
#
#       Property_Shape  LandContour  Utilities  LotConfig  ...  ScreenPorch  \
# ...

# %%
y=df.iloc[:,79]
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2068    214000
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 2073, dtype: int64

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
x= sm.add_constant(x)

model = sm.OLS(y, x).fit()

# %%
summary = model.summary()
print(summary)
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Property_Sale_Price   R-squared:                       0.856
# Model:                             OLS   Adj. R-squared:                  0.850
# Method:                  Least Squares   F-statistic:                     153.9
# Date:                 Sat, 04 Jun 2022   Prob (F-statistic):               0.00
# Time:                         17:03:27   Log-Likelihood:                -24302.
# No. Observations:                 2073   AIC:                         4.876e+04
# Df Residuals:                     1995   BIC:                         4.920e+04
# Df Model:                           77
# Covariance Type:             nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            1.27e+06   1.07e+06      1.183      0.237   -8.35e+05    3.37e+06
# ...

# %%
sm.stats.linear_rainbow(model)
# Out:
# (0.7353056612757638, 0.999999387485588)

# %%
model.params
# Out:
# const             1.269635e+06
# Dwell_Type       -5.311429e+00
# Zone_Class       -1.536750e+03
# LotFrontage      -8.455504e+01
# LotArea           2.232458e-01
# Road_Type         4.009420e+04
# Alley            -1.940337e+02
# Property_Shape   -1.295181e+03
# LandContour       2.018847e+03
# Utilities        -4.185027e+04
# LotConfig         5.185199e+02
# LandSlope         5.844463e+03
# Neighborhood      4.641527e+02
# Condition1       -4.492734e+02
# Condition2       -7.536760e+03
# Dwelling_Type    -4.096079e+03
# HouseStyle       -8.371328e+02
# OverallQual       1.920041e+03
# OverallCond       2.633225e+03
# YearBuilt         7.225836e+01
# YearRemodAdd      7.341183e+01
# RoofStyle         1.744628e+03
# RoofMatl          6.980330e+03
# Exterior1st      -1.595578e+03
# Exterior2nd       1.176853e+03
# MasVnrType        5.769488e+03
# MasVnrArea        4.149766e+01
# ExterQual        -1.311754e+04
# ExterCond         5.738101e+02
# Foundation        1.200374e+03
# ...

# %%
model.rsquared
# Out:
# 0.8558955276405875
